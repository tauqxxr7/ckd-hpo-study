# %% [markdown]
# # CKD HPO Experiments
#
# This notebook is a reproducible workspace for the CKD hyperparameter optimization study. Raw clinical datasets are not included in the repository. Configure local dataset paths before running experiments.

# %%
RANDOM_SEED = 42
N_SPLITS = 5

RANDOM_SEED, N_SPLITS

# %% [markdown]
# ## Suggested Workflow
#
# 1. Load the UCI or locally derived eICU cohort.
# 2. Build preprocessing pipelines fitted only on training folds.
# 3. Train Random Forest, XGBoost, and SVM baselines.
# 4. Compare Grid Search, Random Search, Bayesian Optimization/TPE, CMA-ES, and Hyperband.
# 5. Report F1-score, precision, recall, and runtime as mean ± standard deviation where applicable.

# %%
# Example imports after installing requirements.txt
import pandas as pd
from src.preprocessing import split_features_target
from src.train_models import build_model
from src.evaluate import evaluate_binary_classifier
